# %%
# Import required packages
import matplotlib.pyplot as plt
from skimage import io
from skimage import data, img_as_float
import skimage.restoration as skiresort

from skimage.restoration import denoise_wavelet
                                 
from skimage.util import random_noise
from skimage.metrics import peak_signal_noise_ratio, mean_squared_error

import numpy as np
import scipy
import os
import pywt

import numbers
from skimage.color import rgb2gray

# %%
os.environ['R_HOME'] = 'C:\Program Files\R\R-4.1.0' #path to R installation (not neeeded in all cases)

# %%
# To run custom R code
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects import FloatVector
from rpy2.rinterface import NULL, NA

# To export data
import pickle 

# For data processing
import pandas as pd

# %%
# Define noise level
sigma = 1

# %%
# Read image
filename = os.path.join('output\\figures\\peppers256.png')
out_path = "output/image-de-noising/"
original_image = io.imread(filename)
image = rgb2gray(original_image)

# Add noise
noisy = random_noise(image, var=sigma**2, seed = 1, mode = "speckle")

# Only look at grey
noisy = rgb2gray(noisy)
# Out:
# <ipython-input-38-ede660943635>:11: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   noisy = rgb2gray(noisy)

# %%
plt.imshow(image, cmap='gray')

# %%
# Image with noise
plt.imshow(noisy, cmap='gray')

# %%
# Define R functions
itses = importr('itses') # For SparseMAD() as itses()
r_sparse_mad = robjects.r['sparse.mad.estimator']

r_source = robjects.r['source']
r_source("R-utility/extra-utility.R")
est_ss  = robjects.r['get.sureshrink.threshold']
est_iterative = robjects.r['itses_saved_speckle']

# %%
# Define custom thresholding functions

# Iterative estimation with soft threshold starting at median
def itses_st(x, sd, store_iterations = True, name = None):
    x = np.ndarray.flatten(x)

    savepath = NULL
    if name: 
        savepath = "output/image-de-noising/wavelets-st/" + name + str(len(x)) + ".RData"
    
    x_vec = FloatVector(x)
    sd_vec = FloatVector([sd])
    threshold = est_iterative(x_vec, 
                             method ="ST",
                             sd = sd_vec,
                             savepath = savepath,
                             debug = True,
                              b = 100,
                              k = 200,
                            )[1]
    return threshold[0]

# Iteartive estimation with hard threshold starting at median
def itses_ht(x, sd, store_iterations = True, name = None):
    x = np.ndarray.flatten(x)

    savepath = NULL
    if name: 
        savepath = "output/image-de-noising/wavelets-ht/" + name + str(len(x)) + ".RData"
    
    x_vec = FloatVector(x)
    sd_vec = FloatVector([sd])
    threshold = est_iterative(x_vec, 
                             method ="HT",
                             sd = sd_vec,
                              b = 100,
                             savepath = savepath,
                             debug = True,
                             )[1]
    
    return threshold[0]

# Run SureShrink from R package ASUS.
def ss(x, sd):
    x = np.ndarray.flatten(x)
    z = x/sd
    z_vec = FloatVector(z)
    threshold = est_ss(z_vec)[0]
    return threshold*sd

# Estiamte noise with SparseMAD
def sparse_mad (detail_coeffs, distribution='Gaussian'):
    detail_coeffs = detail_coeffs[np.nonzero(detail_coeffs)]

    if distribution.lower() != 'gaussian':
        raise ValueError("Only Gaussian noise estimation is currently "
                         "supported")
        
    x = np.ndarray.flatten(detail_coeffs)
    x_vec = FloatVector(x)
    sigma = r_sparse_mad(x_vec, debug = True)[0]
    return sigma

# %%
# Implement custom wavelet denoising based on scikit-image, mostly copy paste from scikit-image source code. 
# scikit-imaage source code can be found at e.g. https://github.com/scikit-image/scikit-image
# New custom code will be higlighted
def _sigma_est_dwt(detail_coeffs, distribution='Gaussian'):
    detail_coeffs = detail_coeffs[np.nonzero(detail_coeffs)]

    if distribution.lower() == 'gaussian':
        # 75th quantile of the underlying, symmetric noise distribution
        denom = scipy.stats.norm.ppf(0.75)
        sigma = np.median(np.abs(detail_coeffs)) / denom
    else:
        raise ValueError("Only Gaussian noise estimation is currently "
                         "supported")
    return sigma

def _scale_sigma_and_image_consistently(image, sigma, multichannel,
                                        rescale_sigma):
    if multichannel:
        if isinstance(sigma, numbers.Number) or sigma is None:
            sigma = [sigma] * image.shape[-1]
        elif len(sigma) != image.shape[-1]:
            raise ValueError(
                "When multichannel is True, sigma must be a scalar or have "
                "length equal to the number of channels")
    if image.dtype.kind != 'f':
        if rescale_sigma:
            range_pre = image.max() - image.min()
        image = img_as_float(image)
        if rescale_sigma:
            range_post = image.max() - image.min()
            # apply the same magnitude scaling to sigma
            scale_factor = range_post / range_pre
            if multichannel:
                sigma = [s * scale_factor if s is not None else s
                         for s in sigma]
            elif sigma is not None:
                sigma *= scale_factor
    elif image.dtype == np.float16:
        image = image.astype(np.float32)
    return image, sigma
def _bayes_thresh(details, var):
    """BayesShrink threshold for a zero-mean details coeff array."""
    # Equivalent to:  dvar = np.var(details) for 0-mean details array
    dvar = np.mean(details*details)
    eps = np.finfo(details.dtype).eps
    thresh = var / np.sqrt(max(dvar - var, eps))
    return thresh
def _universal_thresh(img, sigma):
    """ Universal threshold used by the VisuShrink method """
    return sigma*np.sqrt(2*np.log(img.size))


def _wavelet_threshold(image, wavelet, method='IterativeST', threshold=None,
                       sigma=None, mode='soft', wavelet_levels=None, use_sparse_mad_estimation = False, name = None):
    # Note that arguments of _wavelet_threshold is slightly altered from original

    wavelet = pywt.Wavelet(wavelet)

    original_extent = tuple(slice(s) for s in image.shape)

    # Determine the number of wavelet decomposition levels
    if wavelet_levels is None:
        # Determine the maximum number of possible levels for image
        dlen = wavelet.dec_len
        wavelet_levels = pywt.dwtn_max_level(image.shape, wavelet)

        # Skip coarsest wavelet scales (see Notes in docstring).
        wavelet_levels = max(wavelet_levels - 3, 1)

    coeffs = pywt.wavedecn(image, wavelet=wavelet, level=wavelet_levels)
    # Detail coefficients at each decomposition level
    dcoeffs = coeffs[1:]

    #!! Custom Code Start !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    # Add the option of using SparseMAD noise estimation (done across all bands in)
    if sigma is None:
        # Estimate the noise via the method in [2]_
        detail_coeffs = dcoeffs[-1]['d' * image.ndim]
        print("Number of points in noise estimation:", len(detail_coeffs))
        if not use_sparse_mad_estimation:
            sigma = _sigma_est_dwt(detail_coeffs, distribution='Gaussian') 
        else: 
            sigma = sparse_mad(detail_coeffs, distribution='Gaussian') 
        print("Estimated noise:", sigma)
    #!! Custom Code End !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        
    if method is not None and threshold is not None:
        warn(("Thresholding method {} selected.  The user-specified threshold "
              "will be ignored.").format(method))
        
    #!! Custom Code Start !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    # Output the wavelet coefficitnes to study in R (before thresholding)
    if name:
        print("Storing waves")
        data = dcoeffs[len(dcoeffs)-2]
        data = np.array([np.ndarray.flatten(data[level]) for level in data])
        data = np.transpose(data)  
        np.savetxt(out_path + name + ".csv", data, delimiter=",")
    #!! Custom Code End !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    
    if threshold is None:
        print(sigma)
        var = sigma**2
        if method is None:
            raise ValueError(
                "If method is None, a threshold must be provided.")
        elif method == "BayesShrink":
            # The BayesShrink thresholds from [1]_ in docstring
            threshold = [{key: _bayes_thresh(level[key], var) for key in level}
                         for level in dcoeffs]
        elif method == "VisuShrink":
            # The VisuShrink thresholds from [2]_ in docstring
            threshold = _universal_thresh(image, sigma)
        #!! Custom Code Start !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        ## Injecting custom thresholding methods, ITSES-ST, ITSES-HT, and SureShrink
        elif method == "IterativeST":
            if name:
                threshold = [{key: itses_st(level[key], sigma, name = name+key) for key in level}
                             for level in dcoeffs]
            else:
                threshold = [{key: itses_st(level[key], sigma, name = None) for key in level}
                             for level in dcoeffs]
        elif method == "IterativeHT":
            mode = 'hard'
            if name:
                threshold = [{key: itses_ht(level[key], sigma, name = name+key) for key in level}
                             for level in dcoeffs]
            else: 
                threshold = [{key: itses_ht(level[key], sigma, name = None) for key in level}
                             for level in dcoeffs]
        elif method == "SureShrink":
            threshold = [{key: ss(level[key], sigma) for key in level}
                         for level in dcoeffs]
        #!! Custom Code End !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        
        else:
            raise ValueError("Unrecognized method: {}".format(method))
            
            
    #!! Custom Code Start !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    # Print found thresholds for debugging
    print("threshold is:")
    print(threshold)
    #!! Custom Code End !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
   
   
    if np.isscalar(threshold):        
        denoised_detail = [{key: pywt.threshold(level[key],
                                                value=threshold,
                                                mode=mode) for key in level}
                           for level in dcoeffs]
    else:        
        denoised_detail = [{key: pywt.threshold(level[key],
                                                value=thresh[key],
                                                mode=mode) for key in level}
                           for thresh, level in zip(threshold, dcoeffs)]
    denoised_coeffs = [coeffs[0]] + denoised_detail
    return pywt.waverecn(denoised_coeffs, wavelet)[original_extent]
def denoise_wavelet(image, sigma=None, wavelet='db1', mode='soft',
                    wavelet_levels=None, multichannel=False,
                    convert2ycbcr=False, method='BayesShrink',
                    rescale_sigma=True, *, channel_axis=None,
                   use_sparse_mad_estimation = False, name = None):
    multichannel = channel_axis is not None


    # floating-point inputs are not rescaled, so don't clip their output.
    clip_output = image.dtype.kind != 'f'

    if convert2ycbcr and not multichannel:
        raise ValueError("convert2ycbcr requires multichannel == True")

    image, sigma = _scale_sigma_and_image_consistently(image,
                                                       sigma,
                                                       multichannel,
                                                       rescale_sigma)
    
    if multichannel:
        if convert2ycbcr:
            out = color.rgb2ycbcr(image)
            # convert user-supplied sigmas to the new colorspace as well
            if rescale_sigma:
                sigma = _rescale_sigma_rgb2ycbcr(sigma)
            for i in range(3):
                # renormalizing this color channel to live in [0, 1]
                _min, _max = out[..., i].min(), out[..., i].max()
                scale_factor = _max - _min
                if scale_factor == 0:
                    # skip any channel containing only zeros!
                    continue
                channel = out[..., i] - _min
                channel /= scale_factor
                sigma_channel = sigma[i]
                if sigma_channel is not None:
                    sigma_channel /= scale_factor
                out[..., i] = denoise_wavelet(channel,
                                              wavelet=wavelet,
                                              method=method,
                                              sigma=sigma_channel,
                                              mode=mode,
                                              wavelet_levels=wavelet_levels,
                                              rescale_sigma=rescale_sigma)
                out[..., i] = out[..., i] * scale_factor
                out[..., i] += _min
            out = color.ycbcr2rgb(out)
        else:
            out = np.empty_like(image)
            for c in range(image.shape[-1]):
                print("Thresholding color: ", c)
                print("Shape", np.shape(image[..., c]))
                if(name):
                    name = name+"channel_"+str(c)
                out[..., c] = _wavelet_threshold(image[..., c],
                                                 wavelet=wavelet,
                                                 method=method,
                                                 sigma=sigma[c], mode=mode,
                                                 wavelet_levels=wavelet_levels,
                                                use_sparse_mad_estimation =use_sparse_mad_estimation, 
                                                name = name)
    else:
        out = _wavelet_threshold(image, wavelet=wavelet, method=method,
                                 sigma=sigma, mode=mode,
                                 wavelet_levels=wavelet_levels,
                                use_sparse_mad_estimation = use_sparse_mad_estimation, 
                                 name = name)

    if clip_output:
        clip_range = (-1, 1) if image.min() < 0 else (0, 1)
        out = np.clip(out, *clip_range, out=out)
    return out

# %%
# Run deafault methods 
bayes_image= denoise_wavelet(noisy, method ="BayesShrink", multichannel = True)
visu_image = denoise_wavelet(noisy, method ="VisuShrink", multichannel = True)
# Out:
# Number of points in noise estimation: 128
# Estimated noise: 0.18358402291975504
# 0.18358402291975504
# threshold is:
# [{'ad': 0.012020316918923525, 'da': 0.018721719031413616, 'dd': 0.021698935488273473}, {'ad': 0.03582808089767662, 'da': 0.03971749969437462, 'dd': 0.07422209891526212}, {'ad': 0.08018833901674083, 'da': 0.0950567268992522, 'dd': 0.1643108960044259}, {'ad': 0.18230410163656252, 'da': 0.20503675623626924, 'dd': 0.25918082267045217}, {'ad': 0.2619070349542193, 'da': 0.2745332979145903, 'dd': 0.26886568086590457}]
# Number of points in noise estimation: 128
# Estimated noise: 0.18358402291975504
# 0.18358402291975504
# threshold is:
# 0.8646146742377208

# %%
# Storing the original wavelet coefficients
try:
    _ = denoise_wavelet(image, method ="DONOTHING", name = "original_wavelets", multichannel = False)
except:
    print("")
# Out:
# Number of points in noise estimation: 128
# Estimated noise: 0.004805084719544886
# Storing waves
# 0.004805084719544886

# %%
# %%time 
itses_image_st = denoise_wavelet(noisy, method ="IterativeST", use_sparse_mad_estimation = False, name = "stjerten_st_", multichannel = False, sigma = sigma)
# Out:
# Storing waves
# 0.5
# [1] "Starting ITSES. Number of points in data:  64"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 1.26477765366882"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.133421328417436"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.146953399648624"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.165753631941132"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 4 Threshold: 0.135587765480449"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.144113314692549"
# [1] "Starting ITSES. Number of points in data:  64"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.883353938126444"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.100088866402217"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0516565648526762"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0705052717359823"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0617058444304799"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.097749278383125"
# [1] "Starting ITSES. Number of points in data:  64"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.715164381452384"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0802003221308923"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0552917577113189"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0628047685034167"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0473008299264213"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0772281573925142"
# [1] "Starting ITSES. Number of points in data:  256"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.49805966648386"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0382201546000923"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0458602754091554"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0442442950764079"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.04664485348941"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0440303475572116"
# [1] "Starting ITSES. Number of points in data:  256"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.355521221012177"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0433602484743787"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0373745768257875"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0430506052449864"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0433078804747732"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0379253650096053"
# [1] "Starting ITSES. Number of points in data:  256"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.246275800665962"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0194383772498203"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.024050668204705"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0199183250736903"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.019637316430501"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0233017803914925"
# [1] "Starting ITSES. Number of points in data:  1024"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.209092621182773"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0206557096514585"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0189011953953896"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0176738419742602"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0204040148522471"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0186235768740354"
# [1] "Starting ITSES. Number of points in data:  1024"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.197699168402688"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0156158397898301"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0170988065767496"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0167981748866897"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0170468954609097"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0173285180035214"
# [1] "Starting ITSES. Number of points in data:  1024"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.151623397731528"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.011542553971197"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0123851758675486"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0128523752908309"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0123549719598091"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0130057880827649"
# [1] "Starting ITSES. Number of points in data:  4096"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.146283494719858"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0106393233740723"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0118647494538729"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0118441186861337"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0117464857878402"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0111903456203431"
# [1] "Starting ITSES. Number of points in data:  4096"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.140269723198198"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0104647648309153"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0113579883549611"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0109823787614921"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0115057308745519"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0115994233706285"
# [1] "Starting ITSES. Number of points in data:  4096"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.128367352229892"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.00947544138013821"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0109145607531332"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0106032111923125"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0103883002330192"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0106185160304357"
# [1] "Starting ITSES. Number of points in data:  16384"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.127280224550266"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.00940358311320989"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0104597297367899"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0103570634634352"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0105650054528758"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0103524539726869"
# [1] "Starting ITSES. Number of points in data:  16384"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.124032735794677"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.0094543242699516"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0101187247290059"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0104738712313899"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0102724433920273"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0102619179430818"
# [1] "Starting ITSES. Number of points in data:  16384"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.123684695833659"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0.00968503700905178"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.0102404142302454"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.0104872904001764"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.0103294111565437"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.0103573583894006"
# threshold is:
# [{'ad': 0.1441133146925489, 'da': 0.097749278383125, 'dd': 0.0772281573925142}, {'ad': 0.04403034755721162, 'da': 0.03792536500960529, 'dd': 0.023301780391492454}, {'ad': 0.018623576874035427, 'da': 0.017328518003521417, 'dd': 0.013005788082764896}, {'ad': 0.01119034562034306, 'da': 0.011599423370628517, 'dd': 0.010618516030435678}, {'ad': 0.010352453972686882, 'da': 0.01026191794308178, 'dd': 0.01035735838940055}]
# Wall time: 1min 54s

# %%
# %%time 
itses_image_ht= denoise_wavelet(noisy, method ="IterativeHT", sigma = sigma, use_sparse_mad_estimation = False, name = "stjerten_ht_", multichannel = False)
# Out:
# Storing waves
# 0.5
# [1] "Starting ITSES. Number of points in data:  64"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 1.26477765366882"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 0.160287295384562"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 2 Threshold: 0"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Breaking iterations, same threshold as previous iteration."
# [1] "Final threshold is: 0"
# [1] "Starting ITSES. Number of points in data:  64"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.883353938126444"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Breaking iterations, same threshold as previous iteration."
# [1] "Final threshold is: 0"
# [1] "Starting ITSES. Number of points in data:  64"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.715164381452384"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 6400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Breaking iterations, same threshold as previous iteration."
# [1] "Final threshold is: 0"
# [1] "Starting ITSES. Number of points in data:  256"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.49805966648386"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 0.0160151825697113"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.000512993967533701"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 4 Threshold: 0.00484947366642776"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.00372826476369069"
# [1] "Starting ITSES. Number of points in data:  256"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.355521221012177"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Breaking iterations, same threshold as previous iteration."
# [1] "Final threshold is: 0"
# [1] "Starting ITSES. Number of points in data:  256"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.246275800665962"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 0.00211564266117668"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.00296838364376451"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 3 Threshold: 0.00180513364467322"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.00197226419465771"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 25600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.00165831961156671"
# [1] "Starting ITSES. Number of points in data:  1024"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.209092621182773"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 0"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 4.36798608329336e-05"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 4.59600342949065e-05"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 5.11440043574699e-05"
# [1] "Starting ITSES. Number of points in data:  1024"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.197699168402688"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 0.0181132060235729"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 2 Threshold: 0.00044249991718484"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 3 Threshold: 0.00127671845179459"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.00185737879615848"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Final threshold is: 0.00114616435134395"
# [1] "Starting ITSES. Number of points in data:  1024"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.151623397731528"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 0.00182100932518396"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 2 Threshold: 0.00233682455114084"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.00132639219613139"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.000198067259351938"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 102400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.00022915703850285"
# [1] "Starting ITSES. Number of points in data:  4096"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.146283494719858"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 0.00109679159268619"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 2 Threshold: 0.0017999529885373"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 3 Threshold: 0.00128798936846391"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.00015365255151965"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Final threshold is: 0.000896307289053424"
# [1] "Starting ITSES. Number of points in data:  4096"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.140269723198198"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 1 Threshold: 6.33069454367038e-05"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 5.78014296190395e-05"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.000237022477439407"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 4 Threshold: 0.00062126761536904"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.000565220433353561"
# [1] "Starting ITSES. Number of points in data:  4096"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.128367352229892"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 7.63953737921254e-05"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 2 Threshold: 0.000966874252617965"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 3 Threshold: 7.63953737921254e-05"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 4 Threshold: 0.000208539142445636"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 409600points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Final threshold is: 0.000581075867144482"
# [1] "Starting ITSES. Number of points in data:  16384"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.127280224550266"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 7.29472261424343e-05"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 2 Threshold: 0.000550358617577902"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.000393943825247911"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.000124062176745225"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0.00012173535970499"
# [1] "Starting ITSES. Number of points in data:  16384"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.124032735794677"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 0.000284911438610443"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 0.000516686335582461"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0.000479915169387886"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.000420069129378647"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Same as last iteration in spline search."
# [1] "Breaking iterations, same threshold as previous iteration."
# [1] "Final threshold is: 0.000420069129378647"
# [1] "Starting ITSES. Number of points in data:  16384"
# [1] "Using custom noise."
# [1] "Threshold bounds are set to: 0 Inf"
# [1] "Iteration: 0 Threshold: 0.123684695833659"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Search 10"
# [1] "Iteration: 1 Threshold: 0.000144684754093772"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 2 Threshold: 9.81053020793804e-05"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 3 Threshold: 0"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Search 6"
# [1] "Search 7"
# [1] "Search 8"
# [1] "Search 9"
# [1] "Same as last iteration in spline search."
# [1] "Iteration: 4 Threshold: 0.00053597544940247"
# [1] "Starting iterative step using sampling."
# [1] "Now sampling: 1638400points"
# [1] "Using custom noise"
# [1] "Search 1"
# [1] "Search 2"
# [1] "Search 3"
# [1] "Search 4"
# [1] "Search 5"
# [1] "Same as last iteration in spline search."
# [1] "Final threshold is: 0"
# threshold is:
# [{'ad': 0.0, 'da': 0.0, 'dd': 0.0}, {'ad': 0.003728264763690688, 'da': 0.0, 'dd': 0.0016583196115667095}, {'ad': 5.114400435746992e-05, 'da': 0.0011461643513439492, 'dd': 0.00022915703850284958}, {'ad': 0.0008963072890534245, 'da': 0.000565220433353561, 'dd': 0.0005810758671444817}, {'ad': 0.00012173535970499044, 'da': 0.00042006912937864714, 'dd': 0.0}]
# Wall time: 14.9 s

# %%
# %%time 
# Run sure shrink denosing
ss_image= denoise_wavelet(noisy, method ="SureShrink", use_sparse_mad_estimation = False, multichannel = False, sigma = sigma)
# Out:
# 0.5
# threshold is:
# [{'ad': 0.17679967376035144, 'da': 0.09349357253431423, 'dd': 0.18333318733217377}, {'ad': 0.3075502248536237, 'da': 0.3748741645709926, 'dd': 1.6651092223153954}, {'ad': 1.861648705529517, 'da': 1.861648705529517, 'dd': 1.861648705529517}, {'ad': 2.039333980337618, 'da': 2.039333980337618, 'dd': 2.039333980337618}, {'ad': 2.2027324540033493, 'da': 2.2027324540033493, 'dd': 2.2027324540033493}]
# Wall time: 15 ms

# %%
plt.rcParams.update({'font.size': 28})

# %%
sigma
# Out:
# 0.5

# %%
# Plot data
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(30, 25),
                       sharex=True, sharey=True)
fig.tight_layout()
plt.gray()


psnr = str(round(peak_signal_noise_ratio(image, noisy),5))
mse = str(round(mean_squared_error(image, noisy),5))
ax[0, 0].imshow(noisy)
ax[0, 0].axis('off')
ax[0, 0].set_title('a) Noisy \n MSE: '+ mse + "\n PSNR: " + psnr)


psnr = str(round(peak_signal_noise_ratio(image, visu_image),5))
mse = str(round(mean_squared_error(image, visu_image),5))
ax[1, 0].imshow(visu_image)
ax[1, 0].axis('off')
ax[1, 0].set_title('d) VisuShrink \n MSE: '+ mse + "\n PSNR: " + psnr)

psnr = str(round(peak_signal_noise_ratio(image, bayes_image),5))
mse = str(round(mean_squared_error(image, bayes_image),5))
ax[1, 1].imshow(bayes_image)
ax[1, 1].axis('off')
ax[1, 1].set_title('e) BayesShrink\n MSE: '+ mse + "\n PSNR: " + psnr)

psnr = str(round(peak_signal_noise_ratio(image, ss_image),5))
mse = str(round(mean_squared_error(image, ss_image),5))
ax[0, 1].imshow(ss_image)
ax[0, 1].axis('off')
ax[0, 1].set_title('b) SureShrink \n MSE: '+ mse + "\n PSNR: " + psnr)


psnr = str(round(peak_signal_noise_ratio(image, itses_image_st),5))
mse = str(round(mean_squared_error(image, itses_image_st),5))
ax[0, 2].imshow(itses_image_st)
ax[0, 2].axis('off')
ax[0, 2].set_title('c) ITSES-ST (MAD) \n MSE: '+ mse + "\n PSNR: " + psnr)



psnr = str(round(peak_signal_noise_ratio(image, itses_image_ht),5))
mse = str(round(mean_squared_error(image, itses_image_ht),5))
ax[1, 2].imshow(itses_image_ht)
ax[1, 2].axis('off')
ax[1, 2].set_title('f) ITSES-HT (MAD)\n MSE: '+ mse + "\n PSNR: " + psnr)

plt.savefig("output/figures//cat_large.pdf")

plt.show()
